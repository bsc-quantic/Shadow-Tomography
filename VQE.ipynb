# %%
import numpy as np
from qibo.models import VQE
from qibochem.driver.molecule import Molecule
from qibochem.ansatz import hf_circuit, ucc_circuit
from qibo.hamiltonians import SymbolicHamiltonian
from qibo.symbols import I, X, Y, Z
from qibo import Circuit, gates
from qibo.optimizers import optimize
import time


def perform_shadow_snapshots(circuit, shadow_size, num_qubits):

    total_time = time.time()
    times = np.zeros(5)
    # Maps the Pauli measurements to the indeces 0, 1, 2 = X, Y, Z
    Pauli = [gates.X, gates.Y, gates.Z]

    # Measurement basis are chosen at random
    measurement_basis = np.random.randint(0, 3, size = (shadow_size, num_qubits))
    outcomes = np.zeros((shadow_size, num_qubits))

    for i in range(shadow_size):
        # In each snapshot, we perform a measurement in a randomly chosen basis
        c = circuit.copy()
        c.add(gates.M(*range(num_qubits), basis = [Pauli[measurement_basis[i][j]] for j in range(num_qubits)]))
        outcomes[i] = c(nshots = 1).samples(binary = True)[0]

    # Returns both the measurement outcomes and the basis the measurements were performed in
    return (outcomes, measurement_basis)

def calculate_classical_shadow(circuit, shadow_size, num_qubits):

    # Performs the measurements
    outcomes, measurement_basis = perform_shadow_snapshots(circuit, shadow_size, num_qubits)
    

    # Possible states in matrix form
    states = [np.array([[1, 0],[0, 0]]), np.array([[0, 0], [0, 1]])]
    # Matrices to invert the implicit unitary operations performed when measuring in different basis
    unitaries = [gates.H(0).matrix(), gates.H(0).matrix()@gates.S(0).dagger().matrix(), gates.I(0).matrix()]
    shadow = np.full(shadow_size, [1], dtype = np.ndarray)

    # Computes the classical shadows for each snapshots
    for i in range(shadow_size):
        for j in range(num_qubits):
            state = states[int(outcomes[i][j])]
            U = unitaries[measurement_basis[i][j]]
            local_rho = 3*(U.conj().T @ state @ U) - np.eye(2)
            shadow[i] = np.kron(shadow[i], local_rho)
            


    return shadow       

def estimate_energy(circuit, hamiltonian, N, K, num_qubits):
    
    
    shadow = calculate_classical_shadow(circuit, N, num_qubits)
    chunk_size = N//K
    chunk_rhos = np.zeros(K, dtype = np.ndarray)
    for k in range(K):
        for j in range (k*chunk_size, (k + 1)*chunk_size):
            chunk_rhos[k] = chunk_rhos[k] + shadow[j]
        chunk_rhos[k] = chunk_rhos[k]/chunk_size
    
    return np.median([(hamiltonian@chunk_rhos[k]).trace() for k in range(K)])



def cost(theta, qubits, hamiltonian):
    double_excitation = np.eye(16)
    double_excitation[3][3] = np.cos(theta/2)[0]
    double_excitation[12][12] = double_excitation[3][3]
    double_excitation[3][12] = np.sin(theta/2)[0]
    double_excitation[12][3] = -double_excitation[3][12]
    c = Circuit(qubits)
    c.add(gates.X(0))
    c.add(gates.X(1))
    c.add(gates.Unitary(double_excitation, 0, 1, 2, 3))
    e = estimate_energy(c, hamiltonian, 1000, 10, qubits)
    return e


mol = Molecule([('H', (0.0, 0.0, -0.3707)), ('H', (0.0, 0.0, 0.3707))])
mol.run_pyscf()
ham = mol.hamiltonian().matrix
qubits = mol.nso
initial_theta = np.pi

print(mol.hamiltonian().eigenvalues())

optimize(cost, initial_theta, args = (qubits, ham), tol = 1e-6)
# Out:
# converged SCF energy = -1.11668438708534
# [Qibo 0.2.9|INFO|2024-08-08 11:25:41]: Using numpy backend on /CPU:0
# [Qibo 0.2.9|WARNING|2024-08-08 11:25:41]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.9|WARNING|2024-08-08 11:25:41]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [-1.13727017 -0.53870958 -0.53870958 -0.53247901 -0.53247901 -0.53247901
#  -0.44698572 -0.44698572 -0.16990139  0.23780528  0.23780528  0.35243414
#   0.35243414  0.47983612  0.71375399  0.92010672]
# /tmp/ipykernel_746/1956474050.py:73: ComplexWarning: Casting complex values to real discards the imaginary part
#   double_excitation[3][3] = np.cos(theta/2)[0]
# /tmp/ipykernel_746/1956474050.py:75: ComplexWarning: Casting complex values to real discards the imaginary part
#   double_excitation[3][12] = np.sin(theta/2)[0]
# /home/alvarodil/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3542: ComplexWarning: Casting complex values to real discards the imaginary part
#   direc[-1] = direc1
# 85.73129606246948

# %%
import numpy as np
from qibo.models import VQE
from qibochem.driver.molecule import Molecule
from qibochem.ansatz import hf_circuit, ucc_circuit
from qibo.hamiltonians import SymbolicHamiltonian
from qibo.symbols import I, X, Y, Z
from qibo import Circuit, gates
from qibo.optimizers import optimize
from scipy.optimize import Bounds
import time


def perform_shadow_snapshots(circuit, shadow_size, num_qubits):

    total_time = time.time()
    times = np.zeros(5)
    # Maps the Pauli measurements to the indeces 0, 1, 2 = X, Y, Z
    Pauli = [gates.X, gates.Y, gates.Z]

    # Measurement basis are chosen at random
    measurement_basis = np.random.randint(0, 3, size = (shadow_size, num_qubits))
    outcomes = np.zeros((shadow_size, num_qubits))

    for i in range(shadow_size):
        # In each snapshot, we perform a measurement in a randomly chosen basis
        c = circuit.copy()
        c.add(gates.M(*range(num_qubits), basis = [Pauli[measurement_basis[i][j]] for j in range(num_qubits)]))
        outcomes[i] = c(nshots = 1).samples(binary = True)[0]

    # Returns both the measurement outcomes and the basis the measurements were performed in
    return (outcomes, measurement_basis)

def calculate_classical_shadow(circuit, shadow_size, num_qubits):

    # Performs the measurements
    outcomes, measurement_basis = perform_shadow_snapshots(circuit, shadow_size, num_qubits)
    

    # Possible states in matrix form
    states = [np.array([[1, 0],[0, 0]]), np.array([[0, 0], [0, 1]])]
    # Matrices to invert the implicit unitary operations performed when measuring in different basis
    unitaries = [gates.H(0).matrix(), gates.H(0).matrix()@gates.S(0).dagger().matrix(), gates.I(0).matrix()]
    shadow = np.full(shadow_size, [1], dtype = np.ndarray)

    # Computes the classical shadows for each snapshots
    for i in range(shadow_size):
        for j in range(num_qubits):
            state = states[int(outcomes[i][j])]
            U = unitaries[measurement_basis[i][j]]
            local_rho = 3*(U.conj().T @ state @ U) - np.eye(2)
            shadow[i] = np.kron(shadow[i], local_rho)
            


    return shadow       

def estimate_energy(circuit, hamiltonian, N, K, num_qubits):
    
    
    shadow = calculate_classical_shadow(circuit, N, num_qubits)
    chunk_size = N//K
    chunk_rhos = np.zeros(K, dtype = np.ndarray)
    for k in range(K):
        for j in range (k*chunk_size, (k + 1)*chunk_size):
            chunk_rhos[k] = chunk_rhos[k] + shadow[j]
        chunk_rhos[k] = chunk_rhos[k]/chunk_size
    
    return np.median([(hamiltonian@chunk_rhos[k]).trace() for k in range(K)])



def cost(theta, num_qubits, num_layers, rho):
    
    c = Circuit(num_qubits)
    for j in range(num_layers):
        for i in range(num_qubits):
            c.add(gates.RX(i, theta[j*num_qubits + i]))
            c.add(gates.CNOT(i, (i + 1)%num_qubits))
    guess_rho = c().state() 
    return 1 - abs(estimate_energy(c, rho, 1000, 10, num_qubits))
    

num_qubits = 2
num_layers = 10
c = Circuit(num_qubits, density_matrix = True)
rng = np.random.default_rng()
theta = rng.uniform(0,2*np.pi, num_qubits*num_layers)
initial_theta = np.zeros(num_qubits*num_layers)
for j in range(num_layers):
    for i in range(num_qubits):
        c.add(gates.RX(i, theta[j*num_qubits + i]))
        c.add(gates.CNOT(i, (i + 1)%num_qubits))
rho = c().state()

print(theta)


optimize(cost, initial_theta, args = (num_qubits, num_layers, rho), bounds = Bounds(np.zeros(num_qubits*num_layers), np.full(num_qubits*num_layers, 2*np.pi)))
# Out:
# [1.69456148 1.18097169 2.48253595 2.97949114 1.37723364 3.48766704
#  3.80848844 2.00073083 0.89189821 5.13615752 2.12015594 0.51021749
#  0.24641782 4.61839659 1.06932738 4.24451864 4.6655128  2.99056743
#  2.91629794 5.79307899]
# aaa
# 0.7038481030264871
# (0.7746027044424285-6.938893903907228e-18j)
# aaa
# 0.9294114032385884
# (0.9867969518105046+1.734723475976807e-17j)
# aaa
# 0.8107197523107919
# (0.8341809761709259-3.8163916471489756e-17j)
# aaa
# 0.8022668551663255
# (0.7334443553060584-5.204170427930421e-17j)
# aaa
# 0.7280870758422479
# (0.7590900370261435-5.204170427930421e-17j)
# aaa
# 0.7675186134338884
# (0.7746092618143648-5.204170427930421e-17j)
# aaa
# 0.8278578182453957
# (0.7546787893890003-5.204170427930421e-17j)
# aaa
# 0.7815252535134938
# (0.759093392785798-5.204170427930421e-17j)
# aaa
# 0.7736326437940475
# (0.7573823401418747-4.85722573273506e-17j)
# aaa
# 0.7183986745394361
# (0.7584344793959893-5.204170427930421e-17j)
# aaa
# 0.7041442446034014
# (0.7580313421894305-4.85722573273506e-17j)
# aaa
# 0.7973465074913849
# (0.7577829647077344-5.204170427930421e-17j)
# aaa
# 0.7924239922271312
# (0.7581851442034115-5.204170427930421e-17j)
# aaa
# 0.7786824581219812
# (0.757936400428175-5.204170427930421e-17j)
# aaa
# 0.7590531352666728
# (0.7580900626438052-5.204170427930421e-17j)
# aaa
# 0.7560476381270196
# (0.7579950674575615-5.204170427930421e-17j)
# aaa
# 0.8211065836464194
# (0.7580537675117238-4.85722573273506e-17j)
# aaa
# 0.869682259240635
# (0.7580174849861754-5.204170427930421e-17j)
# aaa
# 0.8022875353073009
# (0.7580399073319001-5.204170427930421e-17j)
# aaa
# 0.8015436677345809
# (0.7580260489916139-5.204170427930421e-17j)
# aaa
# 0.7639821736697898
# (0.7580346646263546-5.204170427930421e-17j)
# aaa
# 0.9381838480868789
# (0.8812896940569193+4.163336342344337e-17j)
# aaa
# 0.8635993945851794
# (0.8602903921126577+5.551115123125783e-17j)
# aaa
# 0.7763895777120172
# (0.8017749987195205-2.7755575615628914e-17j)
# aaa
# 0.7836862474207724
# (0.7711089099090698-5.551115123125783e-17j)
# aaa
# 0.8005334494034685
# (0.7899204192382017-4.163336342344337e-17j)
# aaa
# 0.7628561623982864
# (0.8247713387704478+2.7755575615628914e-17j)
# aaa
# 0.9070975621710089
# (0.8390528432819706+0j)
# aaa
# 0.7620923852065327
# (0.8158590726108981+0j)
# aaa
# 0.8097443955431957
# (0.8193807532600145-2.7755575615628914e-17j)
# aaa
# 0.8531973371376078
# (0.8104040941855746+2.7755575615628914e-17j)
# aaa
# 0.8596716698835172
# (0.8137677189777248-1.3877787807814457e-17j)
# aaa
# 0.8380634304414272
# (0.8172024306106693+0j)
# aaa
# 0.8651946385194728
# (0.8150593007756908+0j)
# aaa
# 0.8792820722630741
# (0.8163718780864375+0j)
# aaa
# 0.7926306085913567
# (0.8155534591845086+0j)
# aaa
# 0.8050928532366266
# (0.816054898715122+2.7755575615628914e-17j)
# aaa
# 0.7836803053063224
# (0.8157423205986287-1.3877787807814457e-17j)
# aaa
# 0.8997194052341331
# (0.8159338643506994+0j)
# aaa
# 0.8500688669661545
# (0.815814474705767+0j)
# aaa
# 0.7589700656151274
# (0.8158876394580841-1.3877787807814457e-17j)
# aaa
# 0.8383639002811768
# (0.8159052953937149+0j)
# aaa
# 0.7857539398055964
# (0.8158767277390218-1.3877787807814457e-17j)
# aaa
# 0.8876760652091583
# (0.8158943833665986+1.3877787807814457e-17j)
# aaa
# 0.8031052164279824
# (0.8158834715297788+2.7755575615628914e-17j)
# aaa
# 0.7678252104592596
# (0.8158902153933356+0j)
# aaa
# 0.5026808646487513
# (0.5480616963155989-2.7755575615628914e-17j)
# aaa
# 0.7497575390748386
# (0.791505537810071-1.3877787807814457e-17j)
# aaa
# 0.5042035012745941
# (0.5596368005423595-2.7755575615628914e-17j)
# aaa
# 0.507240704870866
# (0.5332274299773766-2.7755575615628914e-17j)
# aaa
# 0.6344155739351351
# (0.6175959555792734-2.7755575615628914e-17j)
# aaa
# 0.5214138786869458
# (0.568680132706173-2.7755575615628914e-17j)
# aaa
# 0.5916781512421472
# (0.5378169384425722-2.7755575615628914e-17j)
# aaa
# 0.5413650292800841
# (0.5549694886397943-1.3877787807814457e-17j)
# aaa
# 0.5160330438660801
# (0.5434995975193223-1.3877787807814457e-17j)
# aaa
# 0.682410174270199
# (0.5505545281752324-2.7755575615628914e-17j)
# aaa
# 0.5882678065689083
# (0.5462260037979565-2.7755575615628914e-17j)
# aaa
# 0.5507880803334756
# (0.5489923879927615-5.551115123125783e-17j)
# aaa
# 0.5934885341377265
# (0.5473470341585618-1.3877787807814457e-17j)
# aaa
# 0.5413912148259852
# (0.5484140421519996-2.7755575615628914e-17j)
# aaa
# 0.5278627203320088
# (0.5477867571098944-2.7755575615628914e-17j)
# aaa
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 101
#      96 rho = c().state()
#      98 print(theta)
# --> 101 optimize(cost, initial_theta, args = (num_qubits, num_layers, rho), bounds = Bounds(np.zeros(num_qubits*num_layers), np.full(num_qubits*num_layers, 2*np.pi)))
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/optimizers.py:99, in optimize(loss, initial_parameters, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, compile, processes, backend)
#      95 from qibo.backends import _check_backend
#      97 backend = _check_backend(backend)
# ---> 99 return newtonian(
#     100     loss,
#     101     initial_parameters,
#     102     args,
#     103     method,
#     104     jac,
#     105     hess,
#     106     hessp,
#     107     bounds,
#     108     constraints,
#     109     tol,
#     110     callback,
#     111     options,
#     112     processes,
#     113     backend,
#     114 )
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/optimizers.py:215, in newtonian(loss, initial_parameters, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, processes, backend)
#     212 else:
#     213     from scipy.optimize import minimize
# --> 215     m = minimize(
#     216         loss,
#     217         initial_parameters,
#     218         args=args,
#     219         method=method,
#     220         jac=jac,
#     221         hess=hess,
#     222         hessp=hessp,
#     223         bounds=bounds,
#     224         constraints=constraints,
#     225         tol=tol,
#     226         callback=callback,
#     227         options=options,
#     228     )
#     229 return m.fun, m.x, m
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     720                                **options)
#     721 elif meth == 'powell':
# --> 722     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     723 elif meth == 'cg':
#     724     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3490, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3488 direc1 = direc[i]
#    3489 fx2 = fval
# -> 3490 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3491                                      tol=xtol * 100,
#    3492                                      lower_bound=lower_bound,
#    3493                                      upper_bound=upper_bound,
#    3494                                      fval=fval)
#    3495 if (fx2 - fval) > delta:
#    3496     delta = fx2 - fval
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3178, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3175     return _linesearch_powell(func, p, xi, fval=fval, tol=tol)
#    3176 elif not np.isneginf(bound[0]) and not np.isposinf(bound[1]):
#    3177     # we can use a bounded scalar minimization
# -> 3178     res = _minimize_scalar_bounded(myfunc, bound, xatol=tol / 100)
#    3179     xi = res.x * xi
#    3180     return squeeze(res.fun), p + xi, xi
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2321, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2319 si = np.sign(rat) + (rat == 0)
#    2320 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2321 fu = func(x, *args)
#    2322 num += 1
#    2323 fmin_data = (num, x, fu)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3159, in _linesearch_powell.<locals>.myfunc(alpha)
#    3158 def myfunc(alpha):
# -> 3159     return func(p + alpha*xi)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:526, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     524 ncalls[0] += 1
#     525 # A copy of x is sent to the user function (gh13740)
# --> 526 fx = function(np.copy(x), *(wrapper_args + args))
#     527 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     528 # backwards-compatibility, also allow np.array([1.3]),
#     529 # np.array([[1.3]]) etc.
#     530 if not np.isscalar(fx):
#
# Cell In[43], line 81, in cost(theta, num_qubits, num_layers, rho)
#      79 guess_rho = c().state()
#      80 print("aaa")
# ---> 81 a = 1 - abs(estimate_energy(c, rho, 1000, 100, num_qubits))
#      82 print(a)
#      83 print(1 - (rho@guess_rho).trace())
#
# Cell In[43], line 60, in estimate_energy(circuit, hamiltonian, N, K, num_qubits)
#      57 def estimate_energy(circuit, hamiltonian, N, K, num_qubits):
# ---> 60     shadow = calculate_classical_shadow(circuit, N, num_qubits)
#      61     chunk_size = N//K
#      62     chunk_rhos = np.zeros(K, dtype = np.ndarray)
#
# Cell In[43], line 36, in calculate_classical_shadow(circuit, shadow_size, num_qubits)
#      33 def calculate_classical_shadow(circuit, shadow_size, num_qubits):
#      34
#      35     # Performs the measurements
# ---> 36     outcomes, measurement_basis = perform_shadow_snapshots(circuit, shadow_size, num_qubits)
#      39     # Possible states in matrix form
#      40     states = [np.array([[1, 0],[0, 0]]), np.array([[0, 0], [0, 1]])]
#
# Cell In[43], line 28, in perform_shadow_snapshots(circuit, shadow_size, num_qubits)
#      26     c = circuit.copy()
#      27     c.add(gates.M(*range(num_qubits), basis = [Pauli[measurement_basis[i][j]] for j in range(num_qubits)]))
# ---> 28     outcomes[i] = c(nshots = 1).samples(binary = True)[0]
#      30 # Returns both the measurement outcomes and the basis the measurements were performed in
#      31 return (outcomes, measurement_basis)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/models/circuit.py:1119, in Circuit.__call__(self, initial_state, nshots)
#    1117 def __call__(self, initial_state=None, nshots=1000):
#    1118     """Equivalent to ``circuit.execute``."""
# -> 1119     return self.execute(initial_state=initial_state, nshots=nshots)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/models/circuit.py:1115, in Circuit.execute(self, initial_state, nshots)
#    1111     return GlobalBackend().execute_distributed_circuit(
#    1112         self, initial_state, nshots
#    1113     )
#    1114 else:
# -> 1115     return GlobalBackend().execute_circuit(self, initial_state, nshots)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/backends/numpy.py:420, in NumpyBackend.execute_circuit(self, circuit, initial_state, nshots)
#     417         state = self.cast(initial_state)
#     419     for gate in circuit.queue:
# --> 420         state = gate.apply_density_matrix(self, state, nqubits)
#     422 else:
#     423     if initial_state is None:
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/gates/abstract.py:427, in Gate.apply_density_matrix(self, backend, state, nqubits)
#     426 def apply_density_matrix(self, backend, state, nqubits):
# --> 427     return backend.apply_gate_density_matrix(self, state, nqubits)
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/qibo/backends/numpy.py:229, in NumpyBackend.apply_gate_density_matrix(self, gate, state, nqubits)
#     225     left, right = einsum_utils.apply_gate_density_matrix_string(
#     226         gate.qubits, nqubits
#     227     )
#     228     state = self.np.einsum(right, state, matrixc)
# --> 229     state = self.np.einsum(left, state, matrix)
#     230 return self.np.reshape(state, 2 * (2**nqubits,))
#
# File ~/anaconda3/envs/shadow/lib/python3.10/site-packages/numpy/core/einsumfunc.py:1371, in einsum(out, optimize, *operands, **kwargs)
#    1369     if specified_out:
#    1370         kwargs['out'] = out
# -> 1371     return c_einsum(*operands, **kwargs)
#    1373 # Check the kwargs to avoid a more cryptic error later, without having to
#    1374 # repeat default values here
#    1375 valid_einsum_kwargs = ['dtype', 'order', 'casting']
#
# KeyboardInterrupt:
