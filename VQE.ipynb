# %%
# !pip install qibochem
# Out:
# Collecting qibochem
#   Using cached qibochem-0.0.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting openfermion<2.0,>=1.5 (from qibochem)
#   Using cached openfermion-1.6.1-py3-none-any.whl.metadata (10 kB)
# Collecting pyscf<3.0.0,>=2.4.0 (from qibochem)
#   Using cached pyscf-2.6.2.tar.gz (8.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: qibo>=0.2.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibochem) (0.2.9)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibochem) (1.14.0)
# Collecting cirq-core~=1.0 (from openfermion<2.0,>=1.5->qibochem)
#   Using cached cirq_core-1.4.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting deprecation (from openfermion<2.0,>=1.5->qibochem)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting h5py>=2.8 (from openfermion<2.0,>=1.5->qibochem)
#   Using cached h5py-3.11.0-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: networkx in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from openfermion<2.0,>=1.5->qibochem) (3.3)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from openfermion<2.0,>=1.5->qibochem) (1.26.4)
# Collecting pubchempy (from openfermion<2.0,>=1.5->qibochem)
#   Using cached PubChemPy-1.0.4-py3-none-any.whl
# Collecting requests>=2.18 (from openfermion<2.0,>=1.5->qibochem)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sympy in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from openfermion<2.0,>=1.5->qibochem) (1.13.1)
# Requirement already satisfied: setuptools in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from pyscf<3.0.0,>=2.4.0->qibochem) (69.5.1)
# Requirement already satisfied: cma<4.0.0,>=3.3.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibo>=0.2.0->qibochem) (3.4.0)
# Requirement already satisfied: hyperopt<0.3.0,>=0.2.7 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibo>=0.2.0->qibochem) (0.2.7)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibo>=0.2.0->qibochem) (1.4.2)
# Requirement already satisfied: openqasm3>=0.5.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from openqasm3[parser]>=0.5.0->qibo>=0.2.0->qibochem) (1.0.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from qibo>=0.2.0->qibochem) (0.9.0)
# Collecting attrs>=21.3.0 (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting duet>=0.2.8 (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached duet-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Collecting matplotlib~=3.0 (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached matplotlib-3.9.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting pandas (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting sortedcontainers~=2.0 (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\alvar\appdata\roaming\python\python310\site-packages (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem) (4.12.2)
# Requirement already satisfied: tqdm in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem) (4.66.4)
# Requirement already satisfied: six in c:\users\alvar\appdata\roaming\python\python310\site-packages (from hyperopt<0.3.0,>=0.2.7->qibo>=0.2.0->qibochem) (1.16.0)
# Requirement already satisfied: future in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from hyperopt<0.3.0,>=0.2.7->qibo>=0.2.0->qibochem) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from hyperopt<0.3.0,>=0.2.7->qibo>=0.2.0->qibochem) (3.0.0)
# Requirement already satisfied: py4j in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from hyperopt<0.3.0,>=0.2.7->qibo>=0.2.0->qibochem) (0.10.9.7)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from openqasm3[parser]>=0.5.0->qibo>=0.2.0->qibochem) (4.13.1)
# Collecting charset-normalizer<4,>=2 (from requests>=2.18->openfermion<2.0,>=1.5->qibochem)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.18->openfermion<2.0,>=1.5->qibochem)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.18->openfermion<2.0,>=1.5->qibochem)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.18->openfermion<2.0,>=1.5->qibochem)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\alvar\miniconda3\envs\shadow2\lib\site-packages (from sympy->openfermion<2.0,>=1.5->qibochem) (1.3.0)
# Requirement already satisfied: packaging in c:\users\alvar\appdata\roaming\python\python310\site-packages (from deprecation->openfermion<2.0,>=1.5->qibochem) (24.1)
# Collecting contourpy>=1.0.1 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached fonttools-4.53.1-cp310-cp310-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow>=8 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alvar\appdata\roaming\python\python310\site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: colorama in c:\users\alvar\appdata\roaming\python\python310\site-packages (from tqdm->cirq-core~=1.0->openfermion<2.0,>=1.5->qibochem) (0.4.6)
# Using cached qibochem-0.0.3-py3-none-any.whl (29 kB)
# Using cached openfermion-1.6.1-py3-none-any.whl (1.2 MB)
# Using cached cirq_core-1.4.1-py3-none-any.whl (1.9 MB)
# Using cached h5py-3.11.0-cp310-cp310-win_amd64.whl (3.0 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached duet-0.2.9-py3-none-any.whl (29 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached matplotlib-3.9.1-cp310-cp310-win_amd64.whl (8.0 MB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Building wheels for collected packages: pyscf
#   Building wheel for pyscf (pyproject.toml): started
#   Building wheel for pyscf (pyproject.toml): finished with status 'error'
# Failed to build pyscf
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyscf (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       cmake -SC:\Users\alvar\AppData\Local\Temp\pip-install-0mj52ubv\pyscf_8fc351cea81b4c41bd92bc09a82d1ad7\pyscf\lib -Bbuild\temp.win-amd64
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:16 (project):
#         Running
#
#          'nmake' '-?'
#
#         failed with:
#
#          no such file or directory
#
#
#       CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#       CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#       -- Configuring incomplete, errors occurred!
#       error: command 'C:\\Users\\alvar\\AppData\\Local\\Temp\\pip-build-env-y_8rcovk\\overlay\\Scripts\\cmake.EXE' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyscf
# ERROR: Could not build wheels for pyscf, which is required to install pyproject.toml-based projects

# %%
import numpy as np
import qibo
from qibo.models import VQE

from qibochem.driver.molecule import Molecule
from qibochem.ansatz import hf_circuit, ucc_circuit

# Define the H2 molecule and obtain its 1-/2- electron integrals with PySCF
h2 = Molecule([('H', (0.0, 0.0, 0.0)), ('H', (0.0, 0.0, 0.7))])
h2.run_psi4()
# Generate the molecular Hamiltonian
hamiltonian = h2.hamiltonian()

# Build a UCC circuit ansatz for running VQE
circuit = hf_circuit(h2.nso, h2.nelec)
circuit += ucc_circuit(h2.nso, [0, 1, 2, 3])

# Create and run the VQE, starting with random initial parameters
vqe = VQE(circuit, hamiltonian)

initial_parameters = np.random.uniform(0.0, 2*np.pi, 8)
best, params, extra = vqe.minimize(initial_parameters)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy.core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\__init__.py:144
#     143 try:
# --> 144     from numpy.__config__ import show as show_config
#     145 except ImportError as e:
#
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy.core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\core\__init__.py:50
#      27     msg = """
#      28
#      29 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      48 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      49         __version__, exc)
# ---> 50     raise ImportError(msg)
#      51 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.10 from "c:\Users\alvar\miniconda3\envs\shadow\python.exe"
#   * The NumPy version is: "1.26.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: No module named 'numpy.core._multiarray_umath'
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import qibo
#       3 from qibo.models import VQE
#
# File c:\Users\alvar\miniconda3\envs\shadow\lib\site-packages\numpy\__init__.py:149
#     145 except ImportError as e:
#     146     msg = """Error importing numpy: you should not try to import numpy from
#     147     its source directory; please exit the numpy source tree, and relaunch
#     148     your python interpreter from there."""
# --> 149     raise ImportError(msg) from e
#     151 __all__ = [
#     152     'exceptions', 'ModuleDeprecationWarning', 'VisibleDeprecationWarning',
#     153     'ComplexWarning', 'TooHardError', 'AxisError']
#     155 # mapping of {name: (value, deprecation_msg)}
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- -----------
# antlr4-python3-runtime 4.13.1
# asttokens              2.4.1
# cloudpickle            3.0.0
# cma                    3.4.0
# colorama               0.4.6
# comm                   0.2.2
# debugpy                1.8.2
# decorator              5.1.1
# exceptiongroup         1.2.2
# executing              2.0.1
# future                 1.0.0
# hyperopt               0.2.7
# ipykernel              6.29.5
# ipython                8.26.0
# jedi                   0.19.1
# joblib                 1.4.2
# jupyter_client         8.6.2
# jupyter_core           5.7.2
# matplotlib-inline      0.1.7
# mpmath                 1.3.0
# nest-asyncio           1.6.0
# networkx               3.3
# numpy                  1.26.4
# openqasm3              1.0.0
# packaging              24.1
# parso                  0.8.4
# pip                    24.0
# platformdirs           4.2.2
# prompt_toolkit         3.0.47
# psutil                 6.0.0
# pure-eval              0.2.2
# py4j                   0.10.9.7
# Pygments               2.18.0
# python-dateutil        2.9.0.post0
# pywin32                306
# pyzmq                  26.0.3
# qibo                   0.2.9
# scipy                  1.14.0
# setuptools             69.5.1
# six                    1.16.0
# stack-data             0.6.3
# sympy                  1.13.1
# tabulate               0.9.0
# tornado                6.4.1
# tqdm                   4.66.4
# traitlets              5.14.3
# typing_extensions      4.12.2
# wcwidth                0.2.13
# wheel                  0.43.0
